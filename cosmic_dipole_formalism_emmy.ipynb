# %% [markdown]
# # LSST Kinematic Dipole Analysis
#
# This notebook simulates and analyzes the kinematic dipole from LSST-like data, including:
# - Realistic galaxy catalog generation
# - Kinematic dipole injection
# - Milky Way extinction with spatially varying R_V
# - LSST selection function
# - Tomographic dipole fitting
# - Visualization

# %%
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
import healpy as hp
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.integrate import quad

from iminuit import Minuit
from iminuit.cost import LeastSquares

from Simulation.simulMap import *

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# # --- Step 1: Generate Mock Galaxy Catalog ---

# %%
def generate_galaxies(N, z_min=0.01, z_max=2.0, alpha=-1.2, m_star=-21.0, phi_star=0.01):
    z = np.random.uniform(z_min, z_max, N) # Redshift distribution: dN/dz ~ z^2 exp(-(z/z0)^1.5)
    L = 10**(0.4 * (m_star - np.random.exponential(1/phi_star, N))) # Luminosity function: Schechter
    # Apparent magnitude (simplified)
    m = m_star + 5 * np.log10(L) - 5 * np.log10(1e5) + 25  # Placeholder
    # RA/Dec: isotropic
    ra = np.random.uniform(0, 360, N)
    dec = np.random.uniform(-1, 1, N) #for dec, needs to use sin(dec), between -1 et 1
    dec = np.degrees(np.arcsin(dec))
    return ra, dec, z, m

# %% [markdown]
# ## Alternative version proposed by Gemini:

# %%
def proba_schechter_mag(M, M_star, alpha):
    """Compute the relative probability of a magnitude M.
    M_star is the caracteristic magnitude of Schechter's luminosity function."""
    L_ratio = 10**(0.4 * (M_star - M)) #Conversion magnitude -> relative luminosity L/L*
    return (L_ratio**alpha) * np.exp(-L_ratio)

def generate_schechter_magnitudes(N, M_min=-23, M_max=-15, M_star=-20.44, alpha=-1.1):
    """Generate N randomized absolute magnitudes, by using a reject test and Schechter's law."""
    magnitudes = []
    while len(magnitudes) < N:
        M_test = np.random.uniform(M_min, M_max)
        p_test = np.random.uniform(0, 1) #Probability for rejet test
        if p_test < proba_schechter_mag(M_test, M_star, alpha): magnitudes.append(M_test)         
    return np.array(magnitudes)

def get_dL(zi, H0=67.4, Om=0.315, Ol=0.685, c=3e8):
    '''Compute the luminosity distance depending on the redshift z, the Hubble constant H0, the cosmological parameters Om and Ol, and the speed of ligt c.'''
    inv_Ez = lambda zp: 1.0 / np.sqrt(Om * (1 + zp)**3 + Ol)
    integral, _ = quad(inv_Ez, 0, zi)
    return (c / H0) * (1 + zi) * integral

# %%
def generate_galaxies_corrected(N, z_min=0.01, z_max=1.0, M_min=-23, M_max=-15, M_star=-20.44, alpha=-1.1, sigma_M_star=1.5, rejectTest_M=False, only_coord=False, **kwargs):
    #Cosmological Parameters  (Planck 2018):
    H0 = kwargs.get('H0', 67.4)
    Om = kwargs.get('Om', 0.315)
    Ol = kwargs.get('Ol', 0.685)
    c = kwargs.get('c', 3e5) #speed of ligt in km/s (because H0 is in Km/s/Mpc)
    M_sun = kwargs.get('M_sun', 4.83) #Absolute magnitude of Sun

    #Coord ra, dec, z:
    ra = np.random.uniform(0, 360, N)
    dec = np.random.uniform(-1, 1, N)
    dec = np.degrees(np.arcsin(dec))
    z = np.random.uniform(z_min, z_max, N) #Redshift
    if only_coord: return ra, dec, z

    #Other data:
    dL_mpc = np.array([get_dL(zi, H0, Om, Ol, c) for zi in z]) #luminosity distance in Mpc
    #Absolute magnitudes:
    if rejectTest_M: M = generate_schechter_magnitudes(N, M_min, M_max, M_star, alpha)
    else: M = np.random.normal(M_star, sigma_M_star, N)
    m = M + 5*np.log10(dL_mpc) + 25 #Aparent magnitudes
    L = 10**(0.4 * (M_sun - M)) #luminosities
    return ra, dec, z, m, M, L, dL_mpc

# %% [markdown]
# ## Test ```generate_galaxies``` functions:

# %%
NSIDE = 64
NPIX = hp.nside2npix(NSIDE)
print("Number of pixels = {}".format(NPIX))
NSources = int(1e6)

ra, dec, z, m = generate_galaxies(NSources)
Nsources_px = RADEC2NSource(NSIDE, ra, dec)
hp.projview(Nsources_px, graticule=True, graticule_labels=True);
# Out:
# Number of pixels = 49152
# /tmp/ipykernel_41012/1178668771.py:5: RuntimeWarning: divide by zero encountered in log10
#   m = m_star + 5 * np.log10(L) - 5 * np.log10(1e5) + 25  # Placeholder

# %%
ra, dec, z = generate_galaxies_corrected(NSources, only_coord=True)
Nsources_px = RADEC2NSource(NSIDE, ra, dec)
hp.projview(Nsources_px, graticule=True, graticule_labels=True);

# %% [markdown]
# # --- Step 2: Apply Kinematic Dipole ---

# %%
def apply_dipole(ra, dec, z, v=370*u.km/u.s, dipole_dir=(264*u.deg, 48*u.deg), c=3e5*u.km/u.s):
    sources = SkyCoord(ra=ra*u.deg, dec=dec*u.deg, distance=1*u.Gpc, frame='icrs')
    x, y, z_coords = sources.cartesian.x.value, sources.cartesian.y.value, sources.cartesian.z.value
    dipole = SkyCoord(ra=dipole_dir[0], dec=dipole_dir[1], frame='icrs')
    dx, dy, dz = dipole.cartesian.x.value, dipole.cartesian.y.value, dipole.cartesian.z.value
    print("u_dipole = ", hp.ang2vec(dipole.ra.deg, dipole.dec.deg, lonlat=True))
    beta = (v/c).to(u.dimensionless_unscaled).value
    gamma = 1/np.sqrt(1-beta**2)
    x_new = x + beta*(dx - (x*dx + y*dy + z_coords*dz)*x)
    y_new = y + beta*(dy - (x*dx + y*dy + z_coords*dz)*y)
    z_new = z_coords + beta*(dz - (x*dx + y*dy + z_coords*dz)*z_coords)
    new_c = SkyCoord(x=x_new*u.dimensionless_unscaled, y=y_new*u.dimensionless_unscaled, \
                      z=z_new*u.dimensionless_unscaled, representation_type='cartesian')
    return new_c.spherical.lon.deg, new_c.spherical.lat.deg

# %% [markdown]
# ## Alternative version proposed by Gemini:

# %%
def apply_dipole_corrected(ra, dec, z, v=370*u.km/u.s, dipole_dir=(264*u.deg, 48*u.deg), c=3e5*u.km/u.s):
    sources = SkyCoord(ra=ra*u.deg, dec=dec*u.deg, frame='icrs')
    u_source = sources.cartesian.xyz.value # Vecteur unitaire (x, y, z)
    dipole = SkyCoord(l=dipole_dir[0], b=dipole_dir[1], frame='galactic').icrs
    u_dipole = dipole.cartesian.xyz.value
    #print("u_dipole = ", hp.ang2vec(dipole.ra.deg, dipole.dec.deg, lonlat=True))
    print("u_dipole = ", u_dipole)
    
    beta_vec = (v/c).to(u.dimensionless_unscaled).value * u_dipole
    beta = np.linalg.norm(beta_vec)
    
    dot_product = np.dot(u_dipole, u_source) #=cos(theta), with theta = angle between the "true" direction and the observed direction.
    factor = (1 + dot_product * beta) # Doppler factor for beta << 1.
    u_new = (u_source + beta_vec[:, np.newaxis] if u_source.ndim > 1 else u_source + beta_vec) / factor

    new_c = SkyCoord(x=u_new[0], y=u_new[1], z=u_new[2], representation_type='cartesian', frame='icrs') 
    #return np.new_c.spherical.lon.deg, new_c.spherical.lat.deg
    return hp.vec2ang(u_new.T, lonlat=True)

# %%
ra_dipole, dec_dipole = apply_dipole(ra, dec, z, v=370*u.km/u.s, dipole_dir=(264*u.deg, 48*u.deg))
Nsources_px_dipole = RADEC2NSource(NSIDE, ra_dipole, dec_dipole)
_, dip = hp.fit_dipole(Nsources_px_dipole)
print("Normalized measured dipole =", dip/np.linalg.norm(dip))
print("Measured dipole =", dip)
hp.projview(Nsources_px_dipole, graticule=True, graticule_labels=True);
# Out:
# u_dipole =  [-0.06994319 -0.66546504  0.74314483]
# Normalized measured dipole = [-0.06949288 -0.8548019   0.51428051]
# Measured dipole = [-0.00426945 -0.05251663  0.03159595]

# %%
ra_dipole, dec_dipole = apply_dipole_corrected(ra, dec, z, v=370*u.km/u.s, dipole_dir=(264*u.deg, 48*u.deg))
Nsources_px_dipole = RADEC2NSource(NSIDE, ra_dipole, dec_dipole)
_, dip = hp.fit_dipole(Nsources_px_dipole)
print("Normalized measured dipole =", dip/np.linalg.norm(dip))
print("Measured dipole =", dip)
hp.projview(Nsources_px_dipole, graticule=True, graticule_labels=True);
# Out:
# u_dipole =  [-0.96977598  0.2099102  -0.12438755]
# Normalized measured dipole = [-0.95958362 -0.16295559 -0.22944445]
# Measured dipole = [-0.0492859  -0.00836969 -0.01178467]

# %% [markdown]
# # --- Step 3: Apply Milky Way Extinction with Spatially Varying R_V ---

# %%
def apply_extinction(ra, dec, m, ebv_map=None, rv_map=None):
    # Placeholder: Simulate E(B-V) and R_V maps
    if ebv_map is None:
        ebv = np.random.normal(0.03, 0.01, len(ra))
    if rv_map is None:
        rv = np.random.normal(3.1, 0.3, len(ra))
    A_r = rv * ebv * 2.753
    m_corrected = m + A_r
    return m_corrected

# %% [markdown]
# # --- Step 4: Apply LSST Selection Function ---

# %%
def apply_lsst_selection(ra, dec, m, z):
    in_footprint = (dec > -60) & (dec < 30)
    detected = m < 27.5
    return in_footprint & detected

# %% [markdown]
# # --- Step 5: Tomographic Dipole Fitting ---

# %%
def fit_dipole_tomographic(ra, dec, z, weights, z_bins=[0.1, 0.5, 1.0, 2.0], nest=True):
    results = []
    nside = 32
    npix = hp.nside2npix(nside)
    
    def model(pix, A, l, b):
        pix.dtype = int #because hp.pix2vec needs pix as int
        dipole_dir = hp.ang2vec(np.radians(90-b), np.radians(l))
        pix_vecs = np.array(hp.pix2vec(nside, pix))
        costheta = np.sum(pix_vecs.T * dipole_dir, axis=1)
        #costheta = np.dot(hp.pix2vec(nside, pix), dipole_dir)
        print("costheta =",costheta)
        print("costheta.shape =",costheta.shape)
        return 1 + A * costheta
    
    for z_min, z_max in zip(z_bins[:-1], z_bins[1:]):
        in_bin = (z > z_min) & (z < z_max)
        
        ipix = hp.ang2pix(nside, np.radians(90-dec[in_bin]), np.radians(ra[in_bin]), nest=nest)
        counts = np.bincount(ipix, weights[in_bin], minlength=npix)
        
        try:
            popt, pcov = curve_fit(model, np.arange(npix), counts, p0=[0.001, 264, 48])
            results.append(popt)
        except:
            results.append([np.nan, np.nan, np.nan])
    return results

# %%
def fit_dipole_tomographic_corrected(ra, dec, z, weights, z_bins=[0.1, 0.5, 1.0, 2.0], nest=True):
    results = []
    nside = 32
    npix = hp.nside2npix(nside)
    
    # On définit le modèle à l'extérieur ou on passe nside explicitement
    def model(pix, A, l, b):
        pix_vecs = np.array(hp.pix2vec(nside, pix.astype(int), nest=nest))
        dipole_dir = hp.ang2vec(np.radians(90-b), np.radians(l)) # shape: (3,)
        costheta = np.sum(pix_vecs.T * dipole_dir, axis=1)
        print("costheta =",costheta)
        print("costheta.shape =",costheta.shape)
        return (1 + A * costheta)

    for z_min, z_max in zip(z_bins[:-1], z_bins[1:]):
        in_bin = (z >= z_min) & (z < z_max)
        if np.sum(in_bin) == 0:
            results.append([np.nan, np.nan, np.nan])
            continue
            
        # Création de la carte de comptage (skymap)
        ipix = hp.ang2pix(nside, np.radians(90-dec[in_bin]), np.radians(ra[in_bin]), nest=nest)
        counts = np.bincount(ipix, weights[in_bin], minlength=npix).astype(float)
        
        mean_counts = np.mean(counts)
        pixel_indices = np.arange(npix)

        try:
            # p0: A (amplitude), l (longitude), b (latitude)
            # On ajoute des bornes (bounds) pour aider l'algorithme
            popt, pcov = curve_fit(model, pixel_indices, counts, 
                                   p0=[0.01, 264, 48],
                                   bounds=([0, 0, -90], [1, 360, 90]))
            results.append(popt)
        except Exception as e:
            print(f"Erreur lors du fit pour le bin {z_min}-{z_max}: {e}")
            results.append([np.nan, np.nan, np.nan])
            
    return results

# %% [markdown]
# # --- Step 6: Visualization ---

# %%
def plot_skymap(ra, dec, weights, title):
    nside = 64
    ipix = hp.ang2pix(nside, np.radians(90-dec), np.radians(ra), nest=True)
    m = np.zeros(hp.nside2npix(nside))
    np.add.at(m, ipix, weights)
    hp.mollview(m, title=title, nest=True, cmap='viridis')
    plt.savefig('skymap.png', dpi=200, bbox_inches='tight')
    #plt.close()

def plot_dipole_fits(results, z_bins):
    plt.errorbar(0.5*(np.array(z_bins[:-1])+np.array(z_bins[1:])), [r[0] for r in results], \
                 yerr=[0.0005]*len(results), fmt='o')  # Placeholder error
    plt.xlabel('Redshift')
    plt.ylabel('Dipole Amplitude')
    plt.title('Tomographic Dipole Fit')
    plt.grid(True)
    plt.savefig('dipole_fit.png', dpi=200, bbox_inches='tight')
    #plt.close()

# %% [markdown]
# # --- Generate and Analyze Mock Data ---

# %%
N = 100000  # Number of galaxies
ra, dec, z, m = generate_galaxies(N)
ra_dipole, dec_dipole = apply_dipole(ra, dec, z, dipole_dir=(0*u.deg, 0*u.deg))
m_corrected = apply_extinction(ra_dipole, dec_dipole, m)
selected = apply_lsst_selection(ra_dipole, dec_dipole, m_corrected, z)

# Fit dipole in tomographic bins
results = fit_dipole_tomographic(ra_dipole[selected], dec_dipole[selected], z[selected], np.ones_like(ra_dipole[selected]))

# Generate plots
plot_skymap(ra_dipole, dec_dipole, np.ones_like(ra_dipole), 'Mock Galaxy Sky Map (with Dipole)')
# Out:
# /tmp/ipykernel_41012/1178668771.py:5: RuntimeWarning: divide by zero encountered in log10
#   m = m_star + 5 * np.log10(L) - 5 * np.log10(1e5) + 25  # Placeholder
# /home/victoria/miniconda3/envs/M2Stage/lib/python3.10/site-packages/healpy/pixelfunc.py:717: RuntimeWarning: divide by zero encountered in _pix2vec_ring
#   return pixlib._pix2vec_ring(nside, ipix)
# /home/victoria/miniconda3/envs/M2Stage/lib/python3.10/site-packages/healpy/pixelfunc.py:717: RuntimeWarning: invalid value encountered in _pix2vec_ring
#   return pixlib._pix2vec_ring(nside, ipix)
# /tmp/ipykernel_41012/1264485022.py:23: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(model, np.arange(npix), counts, p0=[0.001, 264, 48])
# u_dipole =  [1.000000e+00 0.000000e+00 6.123234e-17]
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963563        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963563        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963562        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)
# costheta = [0.72963563        nan        nan ...        nan        nan        nan]
# costheta.shape = (12288,)

# %%
plot_dipole_fits(results, z_bins=[0.1, 0.5, 1.0, 2.0])
results
# Out:
# [array([1.00e-03, 2.64e+02, 4.80e+01]),
#  array([1.00e-03, 2.64e+02, 4.80e+01]),
#  array([1.00e-03, 2.64e+02, 4.80e+01])]

# %%
N = 100000  # Number of galaxies
ra, dec, z, m = generate_galaxies(N)
ra_dipole, dec_dipole = apply_dipole(ra, dec, z, dipole_dir=(0*u.deg, 0*u.deg))
m_corrected = apply_extinction(ra_dipole, dec_dipole, m)
selected = apply_lsst_selection(ra_dipole, dec_dipole, m_corrected, z)

# Fit dipole in tomographic bins
results_corrected = fit_dipole_tomographic_corrected(ra_dipole[selected], dec_dipole[selected], z[selected], np.ones_like(ra_dipole[selected]))

# Generate plots
plot_skymap(ra_dipole, dec_dipole, np.ones_like(ra_dipole), 'Mock Galaxy Sky Map (with Dipole)')
# Out:
# /tmp/ipykernel_41012/1178668771.py:5: RuntimeWarning: divide by zero encountered in log10
#   m = m_star + 5 * np.log10(L) - 5 * np.log10(1e5) + 25  # Placeholder
# u_dipole =  [1.000000e+00 0.000000e+00 6.123234e-17]
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.50441707 -0.49876495 -0.4781144  ...  0.37689014  0.40239144
#   0.40552399]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876497 -0.47811442 ...  0.3768901   0.4023914
#   0.40552395]
# costheta.shape = (12288,)
# costheta = [-0.06367649 -0.08736384 -0.08120502 ...  0.16568394  0.16779447
#   0.14620988]
# costheta.shape = (12288,)
# costheta = [-0.06367649 -0.08736384 -0.08120502 ...  0.16568394  0.16779447
#   0.14620988]
# costheta.shape = (12288,)
# costheta = [-0.06367648 -0.08736383 -0.08120501 ...  0.16568395  0.16779447
#   0.14620988]
# costheta.shape = (12288,)
# costheta = [-0.06367648 -0.08736384 -0.08120501 ...  0.16568392  0.16779445
#   0.14620986]
# costheta.shape = (12288,)
# costheta = [-0.02080753 -0.04164153 -0.04164024 ...  0.04169355  0.04169228
#   0.02085961]
# costheta.shape = (12288,)
# costheta = [-0.02080753 -0.04164153 -0.04164024 ...  0.04169355  0.04169228
#   0.02085961]
# costheta.shape = (12288,)
# costheta = [-0.02080753 -0.04164153 -0.04164024 ...  0.04169355  0.04169228
#   0.02085961]
# costheta.shape = (12288,)
# costheta = [-0.02080755 -0.04164155 -0.04164026 ...  0.04169353  0.04169227
#   0.02085959]
# costheta.shape = (12288,)
# costheta = [-0.00883877 -0.02986956 -0.02949326 ...  0.04962089  0.04903266
#   0.02850286]
# costheta.shape = (12288,)
# costheta = [-0.00883877 -0.02986956 -0.02949326 ...  0.04962089  0.04903266
#   0.02850286]
# costheta.shape = (12288,)
# costheta = [-0.00883877 -0.02986956 -0.02949326 ...  0.04962089  0.04903266
#   0.02850286]
# costheta.shape = (12288,)
# costheta = [-0.00883879 -0.02986958 -0.02949328 ...  0.04962088  0.04903264
#   0.02850285]
# costheta.shape = (12288,)
# costheta = [-0.01372427 -0.03471515 -0.03441174 ...  0.048019    0.04767034
#   0.02701815]
# costheta.shape = (12288,)
# costheta = [-0.01372427 -0.03471515 -0.03441174 ...  0.048019    0.04767034
#   0.02701815]
# costheta.shape = (12288,)
# costheta = [-0.01372427 -0.03471515 -0.03441174 ...  0.048019    0.04767034
#   0.02701815]
# costheta.shape = (12288,)
# costheta = [-0.01372428 -0.03471517 -0.03441176 ...  0.04801898  0.04767033
#   0.02701814]
# costheta.shape = (12288,)
# costheta = [-0.01471992 -0.03570572 -0.0354109  ...  0.04781985  0.04752002
#   0.0268431 ]
# costheta.shape = (12288,)
# costheta = [-0.01471992 -0.03570572 -0.0354109  ...  0.04781985  0.04752002
#   0.0268431 ]
# costheta.shape = (12288,)
# costheta = [-0.01471992 -0.03570572 -0.0354109  ...  0.04781985  0.04752002
#   0.0268431 ]
# costheta.shape = (12288,)
# costheta = [-0.01471994 -0.03570574 -0.03541092 ...  0.04781984  0.04752001
#   0.02684308]
# costheta.shape = (12288,)
# costheta = [-0.01463174 -0.03562221 -0.03531814 ...  0.04801024  0.04770609
#   0.02703153]
# costheta.shape = (12288,)
# costheta = [-0.01463174 -0.03562221 -0.03531814 ...  0.04801024  0.04770609
#   0.02703153]
# costheta.shape = (12288,)
# costheta = [-0.01463174 -0.03562221 -0.03531814 ...  0.04801024  0.04770609
#   0.02703153]
# costheta.shape = (12288,)
# costheta = [-0.01463175 -0.03562222 -0.03531816 ...  0.04801022  0.04770607
#   0.02703152]
# costheta.shape = (12288,)
# costheta = [-0.0146087  -0.0355998  -0.03529452 ...  0.04803559  0.04773031
#   0.02705635]
# costheta.shape = (12288,)
# costheta = [-0.0146087  -0.0355998  -0.03529452 ...  0.04803559  0.04773031
#   0.02705635]
# costheta.shape = (12288,)
# costheta = [-0.0146087  -0.0355998  -0.03529452 ...  0.04803559  0.04773031
#   0.02705635]
# costheta.shape = (12288,)
# costheta = [-0.01460872 -0.03559981 -0.03529453 ...  0.04803557  0.04773029
#   0.02705633]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.50441707 -0.49876495 -0.4781144  ...  0.37689014  0.40239144
#   0.40552399]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876497 -0.47811442 ...  0.3768901   0.4023914
#   0.40552395]
# costheta.shape = (12288,)
# costheta = [ 0.00517391 -0.01803614 -0.01310698 ...  0.14247238  0.14120223
#   0.12121222]
# costheta.shape = (12288,)
# costheta = [ 0.00517391 -0.01803614 -0.01310698 ...  0.14247238  0.14120223
#   0.12121222]
# costheta.shape = (12288,)
# costheta = [ 0.00517392 -0.01803613 -0.01310698 ...  0.14247238  0.14120223
#   0.12121222]
# costheta.shape = (12288,)
# costheta = [ 0.0051739  -0.01803614 -0.01310699 ...  0.14247236  0.14120221
#   0.1212122 ]
# costheta.shape = (12288,)
# costheta = [-0.02080653 -0.04164052 -0.04163926 ...  0.04169307  0.04169176
#   0.02085911]
# costheta.shape = (12288,)
# costheta = [-0.02080653 -0.04164052 -0.04163926 ...  0.04169307  0.04169176
#   0.02085911]
# costheta.shape = (12288,)
# costheta = [-0.02080653 -0.04164052 -0.04163926 ...  0.04169307  0.04169176
#   0.02085911]
# costheta.shape = (12288,)
# costheta = [-0.02080655 -0.04164054 -0.04163927 ...  0.04169306  0.04169174
#   0.02085909]
# costheta.shape = (12288,)
# costheta = [ 0.00867649 -0.01289004 -0.01144356 ...  0.07181514  0.07036855
#   0.05030474]
# costheta.shape = (12288,)
# costheta = [ 0.00867649 -0.01289004 -0.01144356 ...  0.07181514  0.07036855
#   0.05030474]
# costheta.shape = (12288,)
# costheta = [ 0.00867649 -0.01289004 -0.01144356 ...  0.07181514  0.07036855
#   0.05030474]
# costheta.shape = (12288,)
# costheta = [ 0.00867648 -0.01289005 -0.01144358 ...  0.07181512  0.07036854
#   0.05030472]
# costheta.shape = (12288,)
# costheta = [-0.00060661 -0.02194653 -0.02095482 ...  0.06234443  0.06135271
#   0.04104302]
# costheta.shape = (12288,)
# costheta = [-0.00060661 -0.02194653 -0.02095482 ...  0.06234443  0.06135271
#   0.04104302]
# costheta.shape = (12288,)
# costheta = [-0.00060661 -0.02194653 -0.02095482 ...  0.06234443  0.06135271
#   0.04104302]
# costheta.shape = (12288,)
# costheta = [-0.00060662 -0.02194655 -0.02095484 ...  0.06234441  0.0613527
#   0.041043  ]
# costheta.shape = (12288,)
# costheta = [-0.00264559 -0.02393524 -0.02304347 ...  0.06026231  0.05937053
#   0.03900729]
# costheta.shape = (12288,)
# costheta = [-0.00264559 -0.02393524 -0.02304347 ...  0.06026231  0.05937053
#   0.03900729]
# costheta.shape = (12288,)
# costheta = [-0.00264559 -0.02393524 -0.02304347 ...  0.06026231  0.05937053
#   0.03900729]
# costheta.shape = (12288,)
# costheta = [-0.00264561 -0.02393526 -0.02304348 ...  0.06026229  0.05937051
#   0.03900728]
# costheta.shape = (12288,)
# costheta = [-0.00279097 -0.02407703 -0.02319238 ...  0.06011383  0.05922918
#   0.03886213]
# costheta.shape = (12288,)
# costheta = [-0.00279097 -0.02407703 -0.02319238 ...  0.06011383  0.05922918
#   0.03886213]
# costheta.shape = (12288,)
# costheta = [-0.00279097 -0.02407703 -0.02319238 ...  0.06011383  0.05922918
#   0.03886213]
# costheta.shape = (12288,)
# costheta = [-0.00279099 -0.02407705 -0.02319239 ...  0.06011382  0.05922916
#   0.03886212]
# costheta.shape = (12288,)
# costheta = [-0.00279167 -0.02407771 -0.02319309 ...  0.06011312  0.0592285
#   0.03886143]
# costheta.shape = (12288,)
# costheta = [-0.00279167 -0.02407771 -0.02319309 ...  0.06011312  0.0592285
#   0.03886143]
# costheta.shape = (12288,)
# costheta = [-0.00279167 -0.02407771 -0.02319309 ...  0.06011312  0.0592285
#   0.03886143]
# costheta.shape = (12288,)
# costheta = [-0.00279169 -0.02407773 -0.02319311 ...  0.0601131   0.05922848
#   0.03886142]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876498 -0.47811443 ...  0.3768901   0.40239141
#   0.40552396]
# costheta.shape = (12288,)
# costheta = [-0.50441707 -0.49876495 -0.4781144  ...  0.37689014  0.40239144
#   0.40552399]
# costheta.shape = (12288,)
# costheta = [-0.5044171  -0.49876497 -0.47811442 ...  0.3768901   0.4023914
#   0.40552395]
# costheta.shape = (12288,)
# costheta = [-0.04105222 -0.06059375 -0.06307676 ... -0.00946524 -0.00847198
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105222 -0.06059375 -0.06307676 ... -0.00946524 -0.00847198
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105222 -0.06059376 -0.06307677 ... -0.00946524 -0.00847198
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105221 -0.06059375 -0.06307675 ... -0.00946522 -0.00847196
#  -0.02981914]
# costheta.shape = (12288,)
# costheta = [-0.04105221 -0.06059375 -0.06307676 ... -0.00946524 -0.00847197
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105221 -0.06059375 -0.06307676 ... -0.00946524 -0.00847197
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105222 -0.06059376 -0.06307676 ... -0.00946524 -0.00847197
#  -0.02981916]
# costheta.shape = (12288,)
# costheta = [-0.04105221 -0.06059375 -0.06307675 ... -0.00946522 -0.00847195
#  -0.02981914]
# costheta.shape = (12288,)
# costheta = [-0.03432983 -0.05485719 -0.05543671 ...  0.02952553  0.0301877
#   0.00901538]
# costheta.shape = (12288,)
# costheta = [-0.03432983 -0.05485719 -0.05543671 ...  0.02952553  0.0301877
#   0.00901538]
# costheta.shape = (12288,)
# costheta = [-0.03432983 -0.0548572  -0.05543671 ...  0.02952553  0.0301877
#   0.00901538]
# costheta.shape = (12288,)
# costheta = [-0.03432981 -0.05485718 -0.05543669 ...  0.02952554  0.03018771
#   0.00901539]
# costheta.shape = (12288,)
# costheta = [-0.03415545 -0.05488664 -0.05506159 ...  0.03777259  0.03842615
#   0.01726462]
# costheta.shape = (12288,)
# costheta = [-0.03415545 -0.05488664 -0.05506159 ...  0.03777259  0.03842615
#   0.01726462]
# costheta.shape = (12288,)
# costheta = [-0.03415545 -0.05488664 -0.05506159 ...  0.03777259  0.03842615
#   0.01726462]
# costheta.shape = (12288,)
# costheta = [-0.03415543 -0.05488662 -0.05506157 ...  0.0377726   0.03842615
#   0.01726463]
# costheta.shape = (12288,)
# costheta = [-0.03613821 -0.05677981 -0.05712817 ...  0.03418994  0.03494079
#   0.01372823]
# costheta.shape = (12288,)
# costheta = [-0.03613821 -0.05677981 -0.05712817 ...  0.03418994  0.03494079
#   0.01372823]
# costheta.shape = (12288,)
# costheta = [-0.03613821 -0.05677981 -0.05712817 ...  0.03418994  0.03494079
#   0.01372823]
# costheta.shape = (12288,)
# costheta = [-0.03613819 -0.05677979 -0.05712815 ...  0.03418995  0.0349408
#   0.01372824]
# costheta.shape = (12288,)
# costheta = [-0.035349   -0.0560424  -0.05628969 ...  0.03626885  0.03698097
#   0.01578923]
# costheta.shape = (12288,)
# costheta = [-0.035349   -0.0560424  -0.05628969 ...  0.03626885  0.03698097
#   0.01578923]
# costheta.shape = (12288,)
# costheta = [-0.035349   -0.0560424  -0.05628969 ...  0.03626885  0.03698097
#   0.01578923]
# costheta.shape = (12288,)
# costheta = [-0.03534898 -0.05604238 -0.05628967 ...  0.03626885  0.03698098
#   0.01578924]
# costheta.shape = (12288,)
# costheta = [-0.03577954 -0.05645013 -0.05674175 ...  0.03535497  0.03608822
#   0.01488529]
# costheta.shape = (12288,)
# costheta = [-0.03577954 -0.05645013 -0.05674175 ...  0.03535497  0.03608822
#   0.01488529]
# costheta.shape = (12288,)
# costheta = [-0.03577954 -0.05645013 -0.05674175 ...  0.03535497  0.03608822
#   0.01488529]
# costheta.shape = (12288,)
# costheta = [-0.03577952 -0.0564501  -0.05674173 ...  0.03535497  0.03608822
#   0.0148853 ]
# costheta.shape = (12288,)
# costheta = [-0.03556929 -0.05625224 -0.05651977 ...  0.03585109  0.03657403
#   0.01537661]
# costheta.shape = (12288,)
# costheta = [-0.03556929 -0.05625224 -0.05651977 ...  0.03585109  0.03657403
#   0.01537661]
# costheta.shape = (12288,)
# costheta = [-0.03556929 -0.05625224 -0.05651977 ...  0.0358511   0.03657403
#   0.01537661]
# costheta.shape = (12288,)
# costheta = [-0.03556926 -0.05625222 -0.05651975 ...  0.0358511   0.03657403
#   0.01537661]
# costheta.shape = (12288,)

# %%
plot_dipole_fits(results_corrected, z_bins=[0.1, 0.5, 1.0, 2.0])
results_corrected
# Out:
# [array([ 6.13054241e-01,  2.58467207e-06, -8.94955771e+01]),
#  array([ 7.46592737e-01,  1.71536960e-27, -8.85381854e+01]),
#  array([  1.        , 204.69245182, -89.09934474])]

# %%
results_corrected
# Out:
# [array([ 6.13054241e-01,  2.58467207e-06, -8.94955771e+01]),
#  array([ 7.46592737e-01,  1.71536960e-27, -8.85381854e+01]),
#  array([  1.        , 204.69245182, -89.09934474])]

# %%
results
# Out:
# [array([1.00e-03, 2.64e+02, 4.80e+01]),
#  array([1.00e-03, 2.64e+02, 4.80e+01]),
#  array([1.00e-03, 2.64e+02, 4.80e+01])]

# %% [markdown]
# ## Notes
# - Replace placeholder extinction and R_V maps with real data (e.g., from Planck or GAIA).
# - Adjust the LSST selection function as needed (e.g., using CatSim).
# - For more details, see the LSST Science Book and the references therein.
